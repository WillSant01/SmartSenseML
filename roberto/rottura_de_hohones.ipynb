# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Deker\Desktop\The Void\Python\SmartSenseML\roberto\UP\up1.csv")

plt.figure(figsize=(14, 7))

plt.plot(df.index, df['GyroX'], label='GyroX', color='blue')
plt.plot(df.index, df['GyroY'], label='GyroY', color='green')
plt.plot(df.index, df['GyroZ'], label='GyroZ', color='red')

plt.xlabel('N° record')
plt.ylabel('Valore')
plt.title('df')

plt.xticks(np.arange(0, len(df), step=20))
plt.xticks(rotation=45)

plt.legend()
plt.grid(True)

plt.show()

# %%
numero=420

df1=df.iloc[:numero,:]
df2=df.iloc[numero:,:]

plt.figure(figsize=(14, 7))

plt.plot(df1.index, df1['GyroX'], label='GyroX', color='blue')
plt.plot(df1.index, df1['GyroY'], label='GyroY', color='green')
plt.plot(df1.index, df1['GyroZ'], label='GyroZ', color='red')

plt.xlabel('N° record')
plt.ylabel('Valore')
plt.title('df')

plt.xticks(np.arange(0, len(df1), step=10))
plt.xticks(rotation=90)

plt.legend()
plt.grid(True)

plt.show()


plt.figure(figsize=(14, 7))

plt.plot(df2.index, df2['GyroX'], label='GyroX', color='blue')
plt.plot(df2.index, df2['GyroY'], label='GyroY', color='green')
plt.plot(df2.index, df2['GyroZ'], label='GyroZ', color='red')

plt.xlabel('N° record')
plt.ylabel('Valore')
plt.title('df')

plt.xticks(np.arange(numero, len(df), step=10))
plt.xticks(rotation=90)

plt.legend()
plt.grid(True)

plt.show()
