# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fold_left = "../roberto/LEFT/"
fold_rest = "../roberto/REST/"

test = pd.read_csv("../TEST_csv/test_df_ufficiale.csv", index_col=0)
left = pd.read_csv(fold_left + 'left5.csv', index_col=0)

# %%
plt.figure(figsize=(14, 7))

plt.plot(left.index, left['GyroX'], label='GyroX', color='blue')
plt.plot(left.index, left['GyroY'], label='GyroY', color='green')
plt.plot(left.index, left['GyroZ'], label='GyroZ', color='red')

plt.xlabel('N° record')
plt.ylabel('Valore')
plt.title('VEDI dove dividerlo a metà')

plt.xticks(np.arange(0, len(left), step=15))
plt.xticks(rotation=45)

plt.legend()
plt.grid(True)

plt.show()

# %%
test3 = pd.concat([left.iloc[:75, :], test])

test3.to_csv("../TEST_csv/test_df_ufficiale3.csv")
