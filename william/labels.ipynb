# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cartella = r"..\roberto\UP"
df = pd.read_csv(cartella + "/up10.csv", index_col=0)

df.head()
# Out:
#      Timestamp     AccX     AccY     AccZ    GyroX    GyroY    GyroZ
# 0  11:51:10.90 -5.65000  6.44539  0.18391  0.06667  0.00000 -0.00000
# 1  11:51:10.96 -5.60898  6.29890  0.25143  0.06667  0.00000 -0.00000
# 2  11:51:11.03 -4.71607  5.73072  0.31051  0.03333 -0.03333 -0.03333
# 3  11:51:11.09 -3.79017  5.03563  0.25829  0.00000  0.00000 -0.03333
# 4  11:51:11.15 -2.91261  4.17591  0.19950  0.00000  0.00000 -0.03333

# %%
# ANDAMENTO COMPLETO ---> VEDERE DOVE ANDARE A TAGLIARE IN DUE (non tagliare i gesti)
plt.figure(figsize=(14, 7))

plt.plot(df.index, df['GyroX'], label='GyroX', color='blue')
plt.plot(df.index, df['GyroY'], label='GyroY', color='green')
plt.plot(df.index, df['GyroZ'], label='GyroZ', color='red')

plt.xlabel('N° record')
plt.ylabel('Valore')
plt.title('VEDI dove dividerlo a metà')

plt.xticks(np.arange(0, len(df), step=25))
plt.xticks(rotation=45)

plt.legend()
plt.grid(True)

plt.show()

# %%
num_fortunato = 500
df1 = df.iloc[:num_fortunato,:]
df2 = df.iloc[num_fortunato:,:]

# %%
# ANDAMENTO PRIMA PARTE --> SCRIVERE I RANGE SU CARTA (SALTI DI 50 OBBLIGATORI)
plt.figure(figsize=(20, 7))

plt.plot(df1.index, df1['GyroX'], label='GyroX', color='blue')
plt.plot(df1.index, df1['GyroY'], label='GyroY', color='green')
plt.plot(df1.index, df1['GyroZ'], label='GyroZ', color='red')

plt.xlabel('Timestamp')
plt.ylabel('Valore')
plt.title('PRENDI CARTA E PENNA 1')

plt.xticks(np.arange(0, len(df1), step=5))
plt.xticks(rotation=45)

plt.legend()
plt.grid(True)

plt.show()

# %%
# ANDAMENTO SECONDA PARTE --> SCRIVERE I RANGE SU CARTA (SALTI DI 50 OBBLIGATORI)
plt.figure(figsize=(20, 7))

plt.plot(df2.index, df2['GyroX'], label='GyroX', color='blue')
plt.plot(df2.index, df2['GyroY'], label='GyroY', color='green')
plt.plot(df2.index, df2['GyroZ'], label='GyroZ', color='red')

plt.xlabel('Timestamp')
plt.ylabel('Valore')
plt.title('CHE ANDIAMO ANALOGICI 2')

plt.xticks(np.arange(0+num_fortunato, len(df2)+num_fortunato, step=5))
plt.xticks(rotation=45)

plt.legend()
plt.grid(True)

plt.show()

# %%
#df = df[df.index < 870]

df['label'] = 0

ranges = [(55, 90), (120, 155), (200, 245), (275, 315), (350, 400), (435, 480),
          (520, 570), (605, 650), (685, 730), (755, 800), (830, 870)]

for start, end in ranges:
    df.loc[start:end-1, 'label'] = 1

# %%
#df.to_csv(cartella + "/up10.csv")

# %%
import os

cartella_csv = "../roberto/REST"

for filename in os.listdir(cartella_csv):
    if filename.endswith(".csv"):
        file_path = os.path.join(cartella_csv, filename)

        df = pd.read_csv(file_path, index_col=0)

        df["label"] = 0

        df.to_csv(file_path)

        print(f"Colonna 'label' aggiunta a {filename}")
# Out:
# Colonna 'label' aggiunta a rest1.csv
# Colonna 'label' aggiunta a rest10.csv
# Colonna 'label' aggiunta a rest11.csv
# Colonna 'label' aggiunta a rest12.csv
# Colonna 'label' aggiunta a rest13.csv
# Colonna 'label' aggiunta a rest14.csv
# Colonna 'label' aggiunta a rest15.csv
# Colonna 'label' aggiunta a rest16.csv
# Colonna 'label' aggiunta a rest17.csv
# Colonna 'label' aggiunta a rest18.csv
# Colonna 'label' aggiunta a rest19.csv
# Colonna 'label' aggiunta a rest2.csv
# Colonna 'label' aggiunta a rest20.csv
# Colonna 'label' aggiunta a rest3.csv
# Colonna 'label' aggiunta a rest4.csv
# Colonna 'label' aggiunta a rest5.csv
# Colonna 'label' aggiunta a rest6.csv
# Colonna 'label' aggiunta a rest7.csv
# Colonna 'label' aggiunta a rest8.csv
# Colonna 'label' aggiunta a rest9.csv
